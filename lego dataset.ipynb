# %% [markdown]
# <a href="https://colab.research.google.com/github/vini-moura/R-course-projects/blob/main/lego%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src= '/content/bricks.jpg'>
#
#
# ## SECTION TITLE

# %%
import pandas as pd

cores = pd.read_csv("/content/data/colors.csv")
cores.head()
# Out:
#    id            name     rgb is_trans
# 0  -1         Unknown  0033B2        f
# 1   0           Black  05131D        f
# 2   1            Blue  0055BF        f
# 3   2           Green  237841        f
# 4   3  Dark Turquoise  008F9B        f

# %%
cores['name'].nunique()
# Out:
# 135

# %%
conjuntos = pd.read_csv("/content/data/sets.csv")
conjuntos.head()
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0   001-1                       Gears  1965         1         43
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          0
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %% [markdown]
#     In which year were the first LEGO sets released and what were these sets called?
#
#     How many different products did the LEGO company sell in their first year of operation?
#
#     What are the top 5 LEGO sets with the most number of parts?

# %%
conjuntos.loc[conjuntos.year.idxmin()]
# Out:
# set_num                         700.1-1
# name         Extra-Large Gift Set (ABB)
# year                               1949
# theme_id                            365
# num_parts                           142
# Name: 9521, dtype: object

# %%
conjuntos[conjuntos.year==1949]
# Out:
#       set_num                               name  year  theme_id  num_parts
# 9521  700.1-1         Extra-Large Gift Set (ABB)  1949       365        142
# 9534  700.2-1               Large Gift Set (ABB)  1949       365        178
# 9539  700.3-1              Medium Gift Set (ABB)  1949       365        142
# 9544  700.A-1              Small Brick Set (ABB)  1949       371         24
# 9545  700.B-1  Small Doors and Windows Set (ABB)  1949       371         12

# %%
conjuntos.sort_values('num_parts', ascending=False).head()
# Out:
#         set_num                           name  year  theme_id  num_parts
# 15004  BIGBOX-1  The Ultimate Battle for Chima  2015       571       9987
# 11183   75192-1          UCS Millennium Falcon  2017       171       7541
# 10551   71043-1                Hogwarts Castle  2018       246       6020
# 295     10256-1                      Taj Mahal  2017       673       5923
# 221     10189-1                      Taj Mahal  2008       673       5922

# %% [markdown]
# ## Another section

# %%
import matplotlib.pyplot as plt

cjt_por_ano = conjuntos.groupby('year').count()
cjt_por_ano['set_num'].head(5)
# Out:
# year
# 1949     5
# 1950     6
# 1953     4
# 1954    14
# 1955    28
# Name: set_num, dtype: int64

# %%
#plt.plot(cjt_por_ano.index,cjt_por_ano.num_parts)
plt.plot(cjt_por_ano.index[:-2],cjt_por_ano.num_parts[:-2])
